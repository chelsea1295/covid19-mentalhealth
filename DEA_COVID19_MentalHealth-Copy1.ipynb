# %%
#cite PlayingNumbers/ds_salary_proj [Ken Jee] https://github.com/PlayingNumbers
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('Optimization_Unemployment_1.csv')

# %%
df.head()
# Out:
#    country  started_working_from_home  working_from_home  \
# 0  Ireland                       43.4               43.4
# 1    Spain                       30.2               30.2
# 2   France                       37.2               37.2
# 3  Belgium                       53.4               53.4
# 4  Germany                       36.9               36.9
#
#    optimistic_strongly_agree  optimistic_agree  total_optimism  \
# 0                       13.9              45.4            59.3
# 1                        6.6              34.6            41.2
# 2                        7.7              25.9            33.6
# 3                        7.9              31.9            39.7
# 4                       10.0              42.9            52.8
#
#    day_filled_with_interest  unemployed_perm  unemployed_temp  \
# 0                      30.3              2.9             28.7
# 1                      30.5              6.3             24.4
# ...

# %%
df.columns
# Out:
# Index(['country', 'started_working_from_home', 'working_from_home',
#        'optimistic_strongly_agree', 'optimistic_agree', 'total_optimism',
#        'day_filled_with_interest', 'unemployed_perm', 'unemployed_temp',
#        'total_unemployed'],
#       dtype='object')

# %%
df.started_working_from_home.hist()

# %%
df.total_optimism.hist()

# %%
df.day_filled_with_interest.hist()

# %%
df.total_unemployed.hist()

# %%
df_cat = df[['started_working_from_home', 'working_from_home',
       'optimistic_strongly_agree', 'optimistic_agree', 'total_optimism',
       'day_filled_with_interest', 'unemployed_perm', 'unemployed_temp',
       'total_unemployed']]

# %%
for i in df_cat[['started_working_from_home', 'unemployed_perm','unemployed_temp','total_optimism']].columns:
    cat_num = df_cat[i][:20].value_counts()
    print("graph for %s:total=%d" % (i,len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for started_working_from_home:total=19
# graph for unemployed_perm:total=16
# graph for unemployed_temp:total=18
# graph for total_optimism:total=19

# %%
pd.pivot_table(df, index = ['country','started_working_from_home', 'unemployed_perm','unemployed_temp','total_optimism'])
# Out:
#                                                                                        day_filled_with_interest  \
# country      started_working_from_home unemployed_perm unemployed_temp total_optimism
# Austria      41.5                      4.2             13.7            58.6                                32.5
# Belgium      53.4                      2.6             16.2            39.7                                30.1
# Bulgaria     28.8                      10.6            26.8            48.9                                28.4
# Croatia      27.8                      5.4             22.5            42.0                                32.2
# Cyprus*      33.2                      7.7             36.4            46.8                                31.1
# Czechia      36.5                      3.2             24.9            58.6                                33.9
# ...

# %%
df.columns
# Out:
# Index(['country', 'started_working_from_home', 'working_from_home',
#        'optimistic_strongly_agree', 'optimistic_agree', 'total_optimism',
#        'day_filled_with_interest', 'unemployed_perm', 'unemployed_temp',
#        'total_unemployed'],
#       dtype='object')

# %%
# Create a dataset (fake)
df = pd.DataFrame(np.random.random((10,4)), columns=['started_working_from_home', 'unemployed_perm','unemployed_temp','total_optimism'])
 
# Calculate correlation between each pair of variable
corr_matrix=df.corr()
 
# plot it
sns.heatmap(corr_matrix, cmap='PuOr')
#sns.plt.show()

# %%
df['started_working_from_home'] = df['started_working_from_home'].astype(float)

# %%
df['optimistic_strongly_agree'] = df['optimistic_strongly_agree'].astype(float)

# %%
df['working_from_home'] = df['working_from_home'].astype(float)

# %%
df['optimistic_agree'] = df['optimistic_agree'].astype(float)

# %%
df['total_optimism'] = df['total_optimism'].astype(float)

# %%
df['day_filled_with_interest'] = df['day_filled_with_interest'].astype(float)

# %%
df['unemployed_perm'] = df['unemployed_perm'].astype(float)

# %%
df['unemployed_temp'] = df['unemployed_temp'].astype(float)

# %%
df['total_unemployed'] = df['total_unemployed'].astype(float)

# %%
df.columns
# Out:
# Index(['country', 'started_working_from_home', 'working_from_home',
#        'optimistic_strongly_agree', 'optimistic_agree', 'total_optimism',
#        'day_filled_with_interest', 'unemployed_perm', 'unemployed_temp',
#        'total_unemployed'],
#       dtype='object')

# %%
df.dtypes
# Out:
# country                       object
# started_working_from_home    float64
# working_from_home            float64
# optimistic_strongly_agree    float64
# optimistic_agree             float64
# total_optimism               float64
# day_filled_with_interest     float64
# unemployed_perm              float64
# unemployed_temp              float64
# total_unemployed             float64
# dtype: object

# %%
df.plot()

# %%
df['country'] = df['country'].astype('|S80')

# %%
df.columns
# Out:
# Index(['country', 'started_working_from_home', 'working_from_home',
#        'optimistic_strongly_agree', 'optimistic_agree', 'total_optimism',
#        'day_filled_with_interest', 'unemployed_perm', 'unemployed_temp',
#        'total_unemployed'],
#       dtype='object')

# %%
df.groupby("country")['total_unemployed'].mean()
# Out:
# country
# b'Austria'         17.9
# b'Belgium'         18.8
# b'Bulgaria'        37.4
# b'Croatia'         27.8
# b'Cyprus*'         44.1
# b'Czechia'         28.0
# b'Denmark'          9.5
# b'Estonia'         18.6
# b'Finland'         23.9
# b'France'          29.8
# b'Germany'         25.4
# b'Greece'          46.5
# b'Hungary'         24.7
# b'Ireland'         31.6
# b'Italy'           34.3
# b'Latvia*'         22.5
# b'Lithuania'       24.3
# b'Luxembourg'      14.5
# b'Malta*'          28.0
# b'Netherlands*'    15.4
# b'Poland'          30.2
# b'Portugal'        29.3
# b'Romania'         38.7
# b'Slovakia'        22.2
# b'Spain'           30.7
# b'Sweden*'         10.9
# b'Total (EU27)'    28.5
# Name: total_unemployed, dtype: float64

# %%
df.groupby("country")['total_unemployed'].mean().plot(kind='bar')

# %%
df.groupby("country")['total_optimism'].mean().plot(kind='bar')

# %%
fig, ax = plt.subplots()
df.plot(x='country', y=['total_optimism', 'total_unemployed'], ax=ax, legend=True, figsize=(20,10))

# %%
#CITE - CODE https://chrisalbon.com/python/data_visualization/matplotlib_grouped_bar_plot/
# Setting the positions and width for the bars
pos = list(range(len(df['working_from_home']))) 
width = 0.25 
    
# Plotting the bars
fig, ax = plt.subplots(figsize=(40,20))

# Create a bar with pre_score data,
# in position pos,
plt.bar(pos, 
        #using df['pre_score'] data,
        df['working_from_home'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224', 
        # with label the first value in first_name
        label=df['country'][0]) 

# Create a bar with mid_score data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df['mid_score'] data,
        df['day_filled_with_interest'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in first_name
        label=df['country'][1]) 

# Create a bar with post_score data,
# in position pos + some width buffer,
plt.bar([p + width*2 for p in pos], 
        #using df['post_score'] data,
        df['total_optimism'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#FFC222', 
        # with label the third value in first_name
        label=df['country'][2]) 

# Set the y axis label
ax.set_ylabel('total_unemployed')

# Set the chart's title
ax.set_title('Covid-19 and Mental Health')

# Set the position of the x ticks
ax.set_xticks([p + 1.5 * width for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(df['country'])

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, 90] )

# Adding the legend and showing the plot
plt.legend(['working_from_home', 'day_filled_with_interest', 'total_optimism'], loc='upper left')
plt.grid()
plt.show()

# %%
# - CITE https://chrisalbon.com/python/data_visualization/matplotlib_simple_scatterplot/ Set style of scatterplot
sns.set_context("notebook", font_scale=1.1)
sns.set_style("ticks")

# Create scatterplot of dataframe
sns.lmplot('total_unemployed', # Horizontal axis
           'total_optimism', # Vertical axis
           data=df, # Data source
           fit_reg=False, # Don't fix a regression line
           #hue="z",  Set color
           scatter_kws={"marker": "D", # Set marker style
                        "s": 100}) # S marker size

# Set title
plt.title('Unemployment and Optimism')

# Set x-axis label
plt.xlabel('Unemployment')

# Set y-axis label
plt.ylabel('Optimism')
# Out:
# Text(13.756, 0.5, 'Optimism')
